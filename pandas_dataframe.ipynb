# %% [markdown]
# <a href="https://colab.research.google.com/github/piaseckazaneta/data-science-bootcamp/blob/main/pandas_dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Podstawowe struktury danych - pd.DataFrame

# %%
import pandas as pd

# %%
df = pd.DataFrame(data = [12, 12, 32])
df
# Out:
#     0
# 0  12
# 1  12
# 2  32

# %%
df = pd.DataFrame(data = [12, 12, 32], index = ['first', 'second', 'third'], columns = ['col_1'])
df
# Out:
#         col_1
# first      12
# second     12
# third      32

# %%
# DataFrame ze słownikiem
df = pd.DataFrame(data = {'WIG20': ['PKN ORLEN', 'PKO BP'],
                          'mWIG40': ['Amica', 'Playway']})
df
# Out:
#        WIG20   mWIG40
# 0  PKN ORLEN    Amica
# 1     PKO BP  Playway

# %%
df = pd.DataFrame(data =[[10, 12, 13], [23, 12, 10]], index = ['first', 'second'], columns = ['col_1', 'col_2', 'col_3'])
df
# Out:
#         col_1  col_2  col_3
# first      10     12     13
# second     23     12     10

# %%
# Zwróć nazwy kolumn
df.columns
# Out:
# Index(['col_1', 'col_2', 'col_3'], dtype='object')

# %%
# Zwróć indeksy
df.index
# Out:
# Index(['first', 'second'], dtype='object')

# %%
# Zwróć wartości - zwróci w ndarray numpy
df.values
# Out:
# array([[10, 12, 13],
#        [23, 12, 10]])

# %%
# Zwróć informację o obiekcie (non-null - nie ma wartości zerowych)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2 entries, first to second
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   2 non-null      int64
#  1   col_2   2 non-null      int64
#  2   col_3   2 non-null      int64
# dtypes: int64(3)
# memory usage: 172.0+ bytes

# %%
# Zwróć opis obiektu w postaci statystyk
df.describe()
# Out:
#            col_1  col_2     col_3
# count   2.000000    2.0   2.00000
# mean   16.500000   12.0  11.50000
# std     9.192388    0.0   2.12132
# min    10.000000   12.0  10.00000
# 25%    13.250000   12.0  10.75000
# 50%    16.500000   12.0  11.50000
# 75%    19.750000   12.0  12.25000
# max    23.000000   12.0  13.00000

# %% [markdown]
# Selekcja kolumn
